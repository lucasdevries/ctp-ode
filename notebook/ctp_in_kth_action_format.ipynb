# %%
import numpy as np
import glob, os
import matplotlib.pyplot as plt
import cv2

# %%
files = glob.glob(r'C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\kth_action_true\train\*')
for file in files:
    array = np.load(file)

    print(array.dtype)
# Out:
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# ...

# %%
# !dir
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is E259-2783
#
#  Directory of C:\Users\lucasdevries\githubrepos\Vid-ODE\notebook
#
# 02/03/2022  03:36 PM    <DIR>          .
# 02/03/2022  03:36 PM    <DIR>          ..
# 02/03/2022  03:24 PM    <DIR>          .ipynb_checkpoints
# 02/03/2022  03:36 PM            23,795 Untitled.ipynb
#                1 File(s)         23,795 bytes
#                3 Dir(s)  161,631,334,400 bytes free

# %%
def write_array(array, filepath):
    with open(filepath, 'wb') as f:
        np.save(f, array)

# %%
files = glob.glob(r'C:\Users\lucasdevries\surfdrive\Projects\temporal-unet\data\modality_sym_noskul_npy\CTP\*')
for file in files:
    newname = os.path.join(r'C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps', file.split(os.sep)[-1])
    print(newname)
    array = np.load(file)[:,:1,...]
    array = np.repeat(array, 3, axis=1)
    array = np.moveaxis(array, 1, -1)
    print(np.min(array), np.max(array))
    norm_image = cv2.normalize(array, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)

    norm_image = norm_image.astype(np.uint8)
    print(np.min(norm_image), np.max(norm_image))


    write_array(norm_image, newname)
# Out:
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_01.npy
# -0.49866572017678745 0.49991087049774835
# 0 254
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_02.npy
# -0.49944516811806194 0.49999081731464884
# 0 255
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_03.npy
# -0.49924459337939453 0.49998711080499136
# 0 254
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_04.npy
# -0.4994403128678422 0.4999804880814718
# 0 255
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_05.npy
# -0.4993146954372143 0.4999733538019636
# 0 255
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_06.npy
# -0.49875125938778936 0.49997005408901385
# 0 254
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_01_07.npy
# -0.49846482325389596 0.4999483055925126
# 0 255
# C:\Users\lucasdevries\githubrepos\Vid-ODE\dataset\ctps\case_02_00.npy
# -0.49890570075244767 0.4999561887325388
# 0 255
# ...

# %%
# Out:
# (360, 120, 160, 3)
# (390, 120, 160, 3)
# (465, 120, 160, 3)
# (305, 120, 160, 3)
# (378, 120, 160, 3)
# (550, 120, 160, 3)
# (428, 120, 160, 3)
# (390, 120, 160, 3)
# (468, 120, 160, 3)
# (656, 120, 160, 3)
# (456, 120, 160, 3)
# (490, 120, 160, 3)
# (415, 120, 160, 3)
# (425, 120, 160, 3)
# (405, 120, 160, 3)
# (362, 120, 160, 3)
# (428, 120, 160, 3)
# (460, 120, 160, 3)
# (490, 120, 160, 3)
# (522, 120, 160, 3)
# (398, 120, 160, 3)
# (390, 120, 160, 3)
# (385, 120, 160, 3)
# (386, 120, 160, 3)
# (550, 120, 160, 3)
# (440, 120, 160, 3)
# (360, 120, 160, 3)
# (390, 120, 160, 3)
# (345, 120, 160, 3)
# (626, 120, 160, 3)
# (350, 120, 160, 3)
# (324, 120, 160, 3)
# (442, 120, 160, 3)
# (502, 120, 160, 3)
# (414, 120, 160, 3)
# (512, 120, 160, 3)
# (480, 120, 160, 3)
# (428, 120, 160, 3)
# (460, 120, 160, 3)
# (432, 120, 160, 3)
# (570, 120, 160, 3)
# (455, 120, 160, 3)
# (492, 120, 160, 3)
# (585, 120, 160, 3)
# (492, 120, 160, 3)
# (620, 120, 160, 3)
# (380, 120, 160, 3)
# ...
